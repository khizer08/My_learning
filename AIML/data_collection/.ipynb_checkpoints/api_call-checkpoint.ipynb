# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\syed khizer\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\syed khizer\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\syed khizer\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\syed khizer\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\syed khizer\anaconda3\lib\site-packages (from requests) (2026.5.20)

# %%
import requests

# %%
URL = "https://api.alquran.cloud/v1/ayah/random"
res=requests.get(URL)
json_data=res.json()
# json_data

# %%
import pandas as pd

# %%
df=pd.json_normalize(json_data)
df["data.text"]
# Out:
# 0    وَأَعۡطَىٰ قَلِیلࣰا وَأَكۡدَىٰۤ\n
# Name: data.text, dtype: object
