# %%
import os

os.environ["LOKY_MAX_CPU_COUNT"] = "12"
os.environ["OMP_NUM_THREADS"] = "4"

# %%
import seaborn as sns
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(
    n_samples=1000,
    n_features=2,
    centers=4,
    random_state=42
)

# %%
# Visualize
sns.scatterplot(
    x=X[:,0],
    y=X[:,1],
)
# Out:
# <Axes: >

# %%
# K-Means Clustering
from sklearn.cluster import KMeans

# %%
K = 4

model = KMeans(
    n_clusters=K,
    random_state=42
)

# %%
labels = model.fit_predict(X)
# label = cluster number

# %%
sns.scatterplot(
    x=X[:,0],
    y=X[:,1],
    c=labels
)
# Out:
# <Axes: >

# %% [markdown]
# # Choose our K value - Elbow Method, Silhouette Score

# %%
# Elbow Method (Manually)

wcss = []
for k in range(1, 21):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit_predict(X)
    wcss.append(kmeans.inertia_)

# %%
sns.lineplot(x=range(1,21), y=wcss, marker='o')
# Out:
# <Axes: >

# %%
# Elbow Method (Automate)

# !pip install kneed
# Out:
# Collecting kneed
#   Downloading kneed-0.8.6-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\syed khizer\anaconda3\lib\site-packages (from kneed) (2.3.5)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\syed khizer\anaconda3\lib\site-packages (from kneed) (1.16.3)
# Downloading kneed-0.8.6-py3-none-any.whl (10 kB)
# Installing collected packages: kneed
# Successfully installed kneed-0.8.6

# %%
from kneed import KneeLocator

# %%
knee = KneeLocator(range(1, 21), wcss, curve="convex", direction="decreasing")

# %%
print("Optimal K = ",knee.elbow)
# Out:
# Optimal K =  4

# %%
# Silhouette Score
from sklearn.metrics import silhouette_score

# %%
ss = []

for k in range(2, 21):
    kmeans = KMeans(n_clusters=k)
    labels = kmeans.fit_predict(X)
    score = silhouette_score(X, labels)

    ss.append(score)

# %%
# plot - K & ss

sns.lineplot(x=range(2, 21), y=ss, marker='o')
# Out:
# <Axes: >
