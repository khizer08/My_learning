# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\Syed khizer\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import time

# %%
#execution time
size=1_000_000

#python list computation
py_list=list(range(size))
start_time=time.time()
sq_list=[x**2 for x in py_list]
end_time=time.time()
print(f"time consumed by python list {end_time-start_time} seconds")

#numpy arrays computation
np_arr=np.array(py_list)
start_time=time.time()
sq_arr=np_arr**2
end_time=time.time()
print(f"time consumed by numpy arrays {end_time-start_time} seconds")
# Out:
# time consumed by python list 0.07286334037780762 seconds
# time consumed by numpy arrays 0.004094362258911133 seconds

# %%
#memory
import sys

print(f"the size of python list= {sys.getsizeof(py_list) * len(py_list)} bytes")

print(f"the size of numpy array= {np_arr.nbytes} bytes")
# Out:
# the size of python list= 8000056000000 bytes
# the size of numpy array= 8000000 bytes
