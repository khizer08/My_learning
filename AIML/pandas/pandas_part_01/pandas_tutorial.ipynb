# %%
import pandas as pd

# %%
data={
    "name":["khizer","owaise","syed"],
    "cgpa":["9.4","6.8","8.67"]
}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#      name  cgpa
# 0  khizer   9.4
# 1  owaise   6.8
# 2    syed  8.67

# %%
df
# Out:
#      name  cgpa
# 0  khizer   9.4
# 1  owaise   6.8
# 2    syed  8.67
